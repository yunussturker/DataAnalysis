# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv"
baby_names = pd.read_csv(url)

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.drop(["Unnamed: 0", "Id"], axis=1, inplace=True)

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
baby_names.Gender.value_counts()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
names = baby_names.groupby(by="Name")

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
len(names)
# Out:
# 17632

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
names.sum().Count.sort_values(ascending=False).head(1)
# Out:
# Name
# Jacob    242874
# Name: Count, dtype: int64

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
(names.sum().Count == 5).sum()
# Out:
# 2578

# %%
names.head()
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1004923  Gryffin  2014      M    WI      5
# 1004950     Kroy  2014      M    WI      5
# 1004973     Owyn  2014      M    WI      5
# 1005707   Haylea  2005      F    WV      5
# 1012216  Coalton  2012      M    WV      7
#
# [65502 rows x 5 columns]

# %% [markdown]
# ### Step 11. What is the standard deviation of names?

# %%
names.Count.std()
# Out:
# Name
# Aaban       0.000000
# Aadan       0.957427
# Aadarsh          NaN
# Aaden      21.154974
# Aadhav           NaN
#              ...
# Zyra        1.154701
# Zyrah       0.707107
# Zyren            NaN
# Zyria       0.737865
# Zyriah      1.666667
# Name: Count, Length: 17632, dtype: float64

# %% [markdown]
# ### Step 12. Get a summary with the mean, min, max, std and quartiles.

# %%
names.describe().T
# Out:
# Name               Aaban        Aadan  Aadarsh        Aaden  Aadhav  \
# Year  count     2.000000     4.000000      1.0   196.000000     1.0
#       mean   2013.500000  2009.750000   2009.0  2010.015306  2014.0
#       std       0.707107     2.872281      NaN     2.044322     NaN
#       min    2013.000000  2008.000000   2009.0  2005.000000  2014.0
#       25%    2013.250000  2008.000000   2009.0  2008.000000  2014.0
#       50%    2013.500000  2008.500000   2009.0  2010.000000  2014.0
#       75%    2013.750000  2010.250000   2009.0  2011.000000  2014.0
#       max    2014.000000  2014.000000   2009.0  2014.000000  2014.0
# Count count     2.000000     4.000000      1.0   196.000000     1.0
